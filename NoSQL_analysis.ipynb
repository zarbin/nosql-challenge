# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene' : 5}
results = establishments.find(query)

# Use count_documents to display the number of documents in the result
print("Number of documents in result:", establishments.count_documents(query))


# Display the first document in the results using pprint
pprint(results[0])
# Out:
# Number of documents in result: 14002
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63cf00f21cb17d6b32f8addc'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Number of rows in the DataFrame: ", len(df))

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows in the DataFrame:  14002
#                         _id   FHRSID  ChangesByServerID  \
# 0  63cf00f21cb17d6b32f8addc  1043695                  0
# 1  63cf00f21cb17d6b32f8addf   647177                  0
# 2  63cf00f21cb17d6b32f8ade4   289352                  0
# 3  63cf00f21cb17d6b32f8adec   805703                  0
# 4  63cf00f21cb17d6b32f8adef  1495230                  0
# 5  63cf00f21cb17d6b32f8adf1  1068284                  0
# 6  63cf00f21cb17d6b32f8adf3  1043701                  0
# 7  63cf00f21cb17d6b32f8adf9   861820                  0
# 8  63cf00f21cb17d6b32f8adfa   873838                  0
# 9  63cf00f21cb17d6b32f8ae00   861815                  0
#
#   LocalAuthorityBusinessID                    BusinessName  \
# 0             PI/000073616                    The Pavilion
# 1             PI/000041489             Wear Bay Bowls Club
# 2             PI/000002460                        The Ship
# 3             PI/000073221       That Burger - Harbour Arm
# 4             PI/000078175                Lobster & Burger
# 5             PI/000076532                   The Tea Caddy
# 6             PI/000076360                 Pick Up Pintxos
# 7             PI/000074300      Waiting Room - Harbour Arm
# 8             PI/000074304         Hog & Hop - Harbour Arm
# 9             PI/000073853  Bath Tub and Gun - Harbour Arm
#
#               BusinessType  BusinessTypeID         AddressLine1  \
# 0  Restaurant/Cafe/Canteen               1  East Cliff Pavilion
# 1        Pub/bar/nightclub            7843        Wear Bay Road
# 2        Pub/bar/nightclub            7843         23 The Stade
# 3   Takeaway/sandwich shop            7844   Folkestone Harbour
# 4   Takeaway/sandwich shop            7844   Folkestone Harbour
# 5           Mobile caterer            7846   Folkestone Harbour
# 6   Takeaway/sandwich shop            7844   Folkestone Harbour
# 7        Pub/bar/nightclub            7843   Folkestone Harbour
# 8   Takeaway/sandwich shop            7844   Folkestone Harbour
# 9        Pub/bar/nightclub            7843   Folkestone Harbour
#
#             AddressLine2 AddressLine3  ...  \
# 0          Wear Bay Road   Folkestone  ...
# 1             Folkestone         Kent  ...
# 2             Folkestone         Kent  ...
# 3  Harbour Approach Road   Folkestone  ...
# 4  Harbour Approach Road   Folkestone  ...
# 5  Harbour Approach Road   Folkestone  ...
# 6  Harbour Approach Road   Folkestone  ...
# 7  Harbour Approach Road   Folkestone  ...
# 8  Harbour Approach Road   Folkestone  ...
# 9  Harbour Approach Road   Folkestone  ...
#
#                 LocalAuthorityWebSite        LocalAuthorityEmailAddress  \
# 0  http://www.folkestone-hythe.gov.uk  foodteam@folkestone-hythe.gov.uk
# 1  http://www.folkestone-hythe.gov.uk  foodteam@folkestone-hythe.gov.uk
# 2  http://www.folkestone-hythe.gov.uk  foodteam@folkestone-hythe.gov.uk
# 3  http://www.folkestone-hythe.gov.uk  foodteam@folkestone-hythe.gov.uk
# 4  http://www.folkestone-hythe.gov.uk  foodteam@folkestone-hythe.gov.uk
# 5  http://www.folkestone-hythe.gov.uk  foodteam@folkestone-hythe.gov.uk
# 6  http://www.folkestone-hythe.gov.uk  foodteam@folkestone-hythe.gov.uk
# 7  http://www.folkestone-hythe.gov.uk  foodteam@folkestone-hythe.gov.uk
# 8  http://www.folkestone-hythe.gov.uk  foodteam@folkestone-hythe.gov.uk
# 9  http://www.folkestone-hythe.gov.uk  foodteam@folkestone-hythe.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 1.195625, 'latitude': 51.083812}
# 1     {'longitude': 1.196408, 'latitude': 51.086058}
# 2      {'longitude': 1.188537, 'latitude': 51.08084}
# 3  {'longitude': 1.18590330311705, 'latitude': 51...
# 4  {'longitude': 1.18590330311705, 'latitude': 51...
# 5  {'longitude': 1.18590330311705, 'latitude': 51...
# 6  {'longitude': 1.18590330311705, 'latitude': 51...
# 7  {'longitude': 1.18590330311705, 'latitude': 51...
# 8  {'longitude': 1.18590330311705, 'latitude': 51...
# 9  {'longitude': 1.18590330311705, 'latitude': 51...
#
#       Distance NewRatingPending  \
# 0  4591.765489            False
# 1  4591.821311            False
# 2  4591.912145            False
# 3  4591.914705            False
# 4  4591.914705            False
# 5  4591.914705            False
# 6  4591.914705            False
# 7  4591.914705            False
# 8  4591.914705            False
# 9  4591.914705            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'https://api.ratings....
# 8  [{'rel': 'self', 'href': 'https://api.ratings....
# 9  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [10 rows x 28 columns]

# %%
df.shape
# Out:
# (14002, 28)

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query =  {"LocalAuthorityName": {"$regex" :"London"}, "RatingValue": {'$gte' : '4'}}
results = establishments.find(query)

# Use count_documents to display the number of documents in the result
print("Number of documents in result:", establishments.count_documents(query))

# Display the first document in the results using pprint
pprint(results[0])
# Out:
# Number of documents in result: 34
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63cf00f31cb17d6b32f8e32f'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Number of rows in the DataFrame: ", len(df))

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows in the DataFrame:  34
#                         _id   FHRSID  ChangesByServerID  \
# 0  63cf00f31cb17d6b32f8e32f   621707                  0
# 1  63cf00f31cb17d6b32f8e658  1130836                  0
# 2  63cf00f31cb17d6b32f8f19d   293783                  0
# 3  63cf00f31cb17d6b32f8ff99  1315095                  0
# 4  63cf00f31cb17d6b32f8ffa6   294474                  0
# 5  63cf00f31cb17d6b32f906ae   294900                  0
# 6  63cf00f31cb17d6b32f927ad   293756                  0
# 7  63cf00f31cb17d6b32f927b7  1252616                  0
# 8  63cf00f31cb17d6b32f92b78   878523                  0
# 9  63cf00f31cb17d6b32f92b9e   295107                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000035653                             Froottree
# 8             PI/000029844                      Brick Lane Brews
# 9             PI/000020749                      City Bar & Grill
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Other catering premises            7841
# 8  Restaurant/Cafe/Canteen               1
# 9  Restaurant/Cafe/Canteen               1
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                   Tereza Joanne King George V Lock
# 8                       Air side London City Airport
# 9                      London City Airport (Airside)
#
#                        AddressLine2 AddressLine3  ...  \
# 0                       Sheppy Kent               ...
# 1  Cherry Garden Street Rotherhithe     Charlton  ...
# 2              South Benfleet Essex               ...
# 3                           Tilbury     Charlton  ...
# 4                     Tilbury Essex               ...
# 5                            London               ...
# 6                            London               ...
# 7         Woolwich Manor Way London     Charlton  ...
# 8                            London               ...
# 9                            London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 8  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7  {'longitude': 0.0693250000476837, 'latitude': ...
# 8     {'longitude': 0.048006, 'latitude': 51.503733}
# 9  {'longitude': 0.0479655750095844, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4648.300000            False
# 8  4649.173485            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

#'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
degree_search = 0.01
latitude = 51.49
longitude = .08

# query =  {"LocalAuthorityName": {"$regex" :"London"}, "RatingValue": {'$gte' : '4'}}
query = {'geocode.latitude': {'$gte': (latitude-degree_search)},\
                                'geocode.latitude': {'$lte': (latitude+degree_search)},\
                                'geocode.longitude': {'$gte': (longitude-degree_search)},\
                                'geocode.longitude': {'$lte': (longitude+degree_search)},\
                                "RatingValue": {'$eq' : '5'}}
sort = [('scores.Hygiene', -1)]
limit = 5

results = list(establishments.find(query).sort(sort).limit(limit))

# Print the results
pprint(results)
# Out:
# [{'AddressLine1': 'Logistics House',
#   'AddressLine2': 'Beach Road',
#   'AddressLine3': 'Newhaven',
#   'AddressLine4': '',
#   'BusinessName': 'Thai Star Foods Ltd',
#   'BusinessType': 'Importers/Exporters',
#   'BusinessTypeID': 14,
#   'ChangesByServerID': 0,
#   'Distance': 4622.68775537926,
#   'FHRSID': 1412076,
#   'LocalAuthorityBusinessID': 'PI/000066449',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BN9 0BX',
#   'RatingDate': '2021-09-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('63cf00f21cb17d6b32f8d52a'),
#   'geocode': {'latitude': 50.7887344360352, 'longitude': 0.0584929995238781},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1412076',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Unit E7',
#   'AddressLine2': 'Eastside Business Park',
#   'AddressLine3': 'Beach Road',
#   'AddressLine4': '',
#   'BusinessName': 'Mamoosh Ltd',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4622.5695519854335,
#   'FHRSID': 1264191,
#   'LocalAuthorityBusinessID': 'PI/000064924',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BN9 0FB',
#   'RatingDate': '2021-07-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('63cf00f21cb17d6b32f8d520'),
#   'geocode': {'latitude': 50.7882587, 'longitude': 0.06121},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1264191',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Bevan Funnell House',
#   'AddressLine2': 'Norton Road',
#   'AddressLine3': 'Newhaven',
#   'AddressLine4': '',
#   'BusinessName': 'Rough & Ready Wholefoods',
#   'BusinessType': 'Distributors/Transporters',
#   'BusinessTypeID': 7,
#   'ChangesByServerID': 0,
#   'Distance': 4622.785522811689,
#   'FHRSID': 1394055,
#   'LocalAuthorityBusinessID': 'PI/000011404',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BN9 0BZ',
#   'RatingDate': '2022-03-10T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('63cf00f21cb17d6b32f8d552'),
#   'geocode': {'latitude': 50.7909698486328, 'longitude': 0.0580499991774559},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1394055',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}},
#  {'AddressLine1': 'Shakespeare Hall',
#   'AddressLine2': 'Fort Road Recreation Ground',
#   'AddressLine3': 'Fort Road',
#   'AddressLine4': '',
#   'BusinessName': 'Nippers',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4622.780055863303,
#   'FHRSID': 664256,
#   'LocalAuthorityBusinessID': 'PI/000012088',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': '',
#   'RatingDate': '2018-09-10T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('63cf00f21cb17d6b32f8d54c'),
#   'geocode': {'latitude': 50.7852495, 'longitude': 0.0525946},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/664256',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}},
#  {'AddressLine1': 'The Buckle',
#   'AddressLine2': 'Marine Parade',
#   'AddressLine3': 'Seaford',
#   'AddressLine4': '',
#   'BusinessName': 'Buckle B&B',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'ChangesByServerID': 0,
#   'Distance': 4621.5144405665105,
#   'FHRSID': 964681,
#   'LocalAuthorityBusinessID': 'PI/000026347',
#   'LocalAuthorityCode': '105',
#   'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#   'LocalAuthorityName': 'Lewes',
#   'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BN25 2QR',
#   'RatingDate': '2021-01-08T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('63cf00f21cb17d6b32f8d3de'),
#   'geocode': {'latitude': 50.779366, 'longitude': 0.080909},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/964681',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}]

# %%
# Convert result to Pandas DataFrame
df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Number of rows in the DataFrame: ", len(df))

# Display head
df.head()
# Out:
# Number of rows in the DataFrame:  5
#                         _id   FHRSID  ChangesByServerID  \
# 0  63cf00f21cb17d6b32f8d52a  1412076                  0
# 1  63cf00f21cb17d6b32f8d520  1264191                  0
# 2  63cf00f21cb17d6b32f8d552  1394055                  0
# 3  63cf00f21cb17d6b32f8d54c   664256                  0
# 4  63cf00f21cb17d6b32f8d3de   964681                  0
#
#   LocalAuthorityBusinessID              BusinessName  \
# 0             PI/000066449       Thai Star Foods Ltd
# 1             PI/000064924               Mamoosh Ltd
# 2             PI/000011404  Rough & Ready Wholefoods
# 3             PI/000012088                   Nippers
# 4             PI/000026347                Buckle B&B
#
#                         BusinessType  BusinessTypeID         AddressLine1  \
# 0                Importers/Exporters              14      Logistics House
# 1                  Retailers - other            4613              Unit E7
# 2          Distributors/Transporters               7  Bevan Funnell House
# 3            Restaurant/Cafe/Canteen               1     Shakespeare Hall
# 4  Hotel/bed & breakfast/guest house            7842           The Buckle
#
#                   AddressLine2 AddressLine3  ...  \
# 0                   Beach Road     Newhaven  ...
# 1       Eastside Business Park   Beach Road  ...
# 2                  Norton Road     Newhaven  ...
# 3  Fort Road Recreation Ground    Fort Road  ...
# 4                Marine Parade      Seaford  ...
#
#                  LocalAuthorityWebSite           LocalAuthorityEmailAddress  \
# 0  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 1  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 2  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 3  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 4  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 0.0584929995238781, 'latitude': ...
# 1     {'longitude': 0.06121, 'latitude': 50.7882587}
# 2  {'longitude': 0.0580499991774559, 'latitude': ...
# 3   {'longitude': 0.0525946, 'latitude': 50.7852495}
# 4     {'longitude': 0.080909, 'latitude': 50.779366}
#
#       Distance NewRatingPending  \
# 0  4622.687755            False
# 1  4622.569552            False
# 2  4622.785523            False
# 3  4622.780056            False
# 4  4621.514441            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene' : 0}}
# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id': '$LocalAuthorityName',
                          'count': { '$sum': 1 }
                         }
                    }
                
# 3. Sorts the matches from highest to lowest
sort = {'$sort': { 'count': -1 }}

pipeline = [match_query, group_query, sort]
results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print("Number of rows in result: ", len(results))

# Print the first 10 results
results[:10]
# Out:
# Number of rows in result:  55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Number of rows in the DataFrame: ", len(df))

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows in the DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
